# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = MSE = sum((y - yp)**2)/len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 238.783
# The Mean absolute error is 11.624

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
# 這組資料是由Airbnb在Kaggle平台上面發布的競賽"Airbnb New User Bookings"所提供，目的是希望能夠使用者會在哪個國家做出他第一次在這個平台上的訂房
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 資料是由Airbnb官方在Kaggle平台上所提供，當中提供了6份的csv檔案，其中training及test的資料集包含7/1/2014以後開始有第一次活動紀錄使用者的相關資料；在session資料集則是從1/1/2014開始；而user資料集是從2010開始以後的資料。資料是如何蒐集的？其中包含airbnb平台上使用者的匿名使用紀錄，以及在平台上的點擊瀏覽等使用行為。
# 3. 蒐集而來的資料型態為何
# 結構化：類別型資料、數值型資料
#
# 4. 這組資料想解決的問題如何評估
# 根據kaggle上面所說明的評估方式，是利用一個叫做NDCG(Normalized discounted cumulative gain)的方法去做分數的評估，我們前面有提到，最後預測出來的結果會是國家的代碼，而對於每個新的平台user，我們一次可以對他做出最多5種預測，如果你只預測出1個國家，而且還是正確的國家，那麼NDCG的分數就會是1，假設你預測的結果有兩個國家，其中一個是正確的國家，那麼NDCG的分數會是0.6309，最後藉由NDCG的總平均分數來判斷這組機器學習model的表現
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 我覺得第一步要做的是"定義問題"，先去找出在當前的服務當中，我們有什麼問題是需要被解決的；第二步"尋找方法"，去找出所有能夠用來解決這個問題的方法，並留下最可行的幾個方法；第三步"設定目標"，在確認可行方法之後，我們要做的就是去探討達到怎麼樣的目標才算是解決這個問題；第四步"設定假設"，根據我們當前面對的問題以及設定的目標去制定假設，並根據該假設去做接下來的步驟；第五步"資料蒐集"，去蒐集用來檢驗該假設的相關資料；第六步"驗證假設"，根據蒐集到的資料去做相關的分析以及實驗，來驗證這些假設是否正確，如果不正確就必須再回到第四步去做調整；最後一個步驟"實際上路"，根據前面做出來的解決方案去套用在現行的服務上
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 業績=客單價*成交數量，所以如果要提升業績，不外乎就是必須提高客單價或是成交數量；至於如何讓客戶願意化更多的錢或是更願意選擇我們的車隊，直覺地來想就是必須提高顧客的滿意度，所以我們必須要提高顧客對於我們服務的滿意程度才能藉此提高我們的業績
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 假設這個自由載客的車隊所使用的服務平台會自動記錄每筆產生的客戶消費資料，這是我們手中現有的資料，接下來我們需要額外做的事情就是做相關的問卷調查，詢問顧客是什麼樣的因素會影響他們選擇搭乘的車隊，所以我們會再得到一份有關載客服務的評分調查，最主要透過這兩筆資料去做分析。
# 3. 蒐集而來的資料型態為何
# 結構化：類別型資料、數值型資料
# 非結構化：文字(心得感想)
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 藉由比對是否"顧客滿意度的提升與業績的提升有正相關的關係"來評估我們的假設是否正確，前面已經獲得原本客戶的消費資料以及顧客的乘車滿意度的資料；另外也有一份詢問因素的調查，我首先會將客戶的消費資料以及乘車滿意度的資料去做分析，看是否消費的頻率以及金額的多寡與顧客的滿意程度有關係，如果確實有正相關，接下來就必須透過問卷調查所獲得的資料去與現有的服務做比較，來得出公司接下來該優化的方向
